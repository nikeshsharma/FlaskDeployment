# %%
# !pip install dvc
# Out:
# ...
#      |████████████████████████████████| 448 kB 1.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 154 kB 23.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 68 kB 12.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 10.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 70 kB 13.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 116 kB 20.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 46 kB 8.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 41 kB 1.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 45 kB 6.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 60 kB 11.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.3 MB 30.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 168 kB 90.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 516 kB 84.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 199 kB 85.4 MB/s eta 0:00:01
# ...
